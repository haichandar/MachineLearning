# %% [markdown]
# #TEXT GENERATION

# %%
# -*- coding: utf-8 -*-
from __future__ import print_function
"""
Created on Sun Jan 13 15:28:27 2019

@author: Chandar_S

A Recurrent Neural Network (LSTM) implementation example using TensorFlow..
Next word prediction after n_input words learned from text file.
A story is automatically generated if the predicted word is fed back as input.
Author: Rowel Atienza
Project: https://github.com/roatienza/Deep-Learning-Experiments
"""


import numpy as np
import tensorflow as tf
from tensorflow.contrib import rnn
import random
import collections
import time

start_time = time.time()
def elapsed(sec):
    if sec<60:
        return str(sec) + " sec"
    elif sec<(60*60):
        return str(sec/60) + " min"
    else:
        return str(sec/(60*60)) + " hr"


# Target log path
logs_path = 'log/'
writer = tf.summary.FileWriter(logs_path)

# Text file containing words for training
training_file = 'belling_the_cat.txt'

def read_data(fname):
    with open(fname) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    content = [word for i in range(len(content)) for word in content[i].split()]
    content = np.array(content)
    return content

training_data = read_data(training_file)
#print (training_data)

print("Loaded training data...")

def build_dataset(words):
    count = collections.Counter(words).most_common()
#    print (count)
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

dictionary, reverse_dictionary = build_dataset(training_data)
#print (dictionary)
#print (reverse_dictionary)
vocab_size = len(dictionary)

# Parameters
learning_rate = 0.001
training_iters = 50000
display_step = 1000
n_input = 3

# number of units in RNN cell
n_hidden = 512

# tf Graph input
x = tf.placeholder("float", [None, n_input, 1])
y = tf.placeholder("float", [None, vocab_size])

# RNN output node weights and biases
weights = {
    'out': tf.Variable(tf.random_normal([2 * n_hidden, vocab_size]))
}
biases = {
    'out': tf.Variable(tf.random_normal([vocab_size]))
}

def RNN(x, weights, biases):

    # reshape to [1, n_input]
    x = tf.reshape(x, [-1, n_input])

    # Generate a n_input-element sequence of inputs
    # (eg. [had] [a] [general] -> [20] [6] [33])
    x = tf.split(x,n_input,1)

    # 2-layer LSTM, each layer has n_hidden units.
    # Average Accuracy= 95.20% at 50k iter
#    rnn_cell = rnn.MultiRNNCell([tf.nn.rnn_cell.LSTMCell(n_hidden),tf.nn.rnn_cell.LSTMCell(n_hidden)])

    # 1-layer LSTM with n_hidden units but with lower accuracy.
    # Average Accuracy= 90.60% 50k iter
    # Uncomment line below to test but comment out the 2-layer rnn.MultiRNNCell above
    # rnn_cell = rnn.BasicLSTMCell(n_hidden)
    # generate prediction
#    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    '''START: BI-DIRECTION '''
#    fw_cell = tf.nn.rnn_cell.LSTMCell(n_hidden, forget_bias=1.0)

    fw_cell = rnn.MultiRNNCell([tf.nn.rnn_cell.LSTMCell(n_hidden),tf.nn.rnn_cell.LSTMCell(n_hidden)])
    bw_cell = rnn.MultiRNNCell([tf.nn.rnn_cell.LSTMCell(n_hidden),tf.nn.rnn_cell.LSTMCell(n_hidden)])
    # Backward direction cell
#    bw_cell = tf.nn.rnn_cell.LSTMCell(n_hidden, forget_bias=1.0)
    outputs, _, _ =  tf.nn.static_bidirectional_rnn(fw_cell, bw_cell, x,
                                          dtype=tf.float32)
    '''END: BI-DIRECTION '''
   

    # there are n_input outputs but
    # we only want the last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

pred = RNN(x, weights, biases)


# Loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=pred, labels=y))
optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

# Model evaluation
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Create a summary to monitor cost tensor
tf.summary.scalar("Model Loss", cost)
# Create a summary to monitor accuracy tensor
tf.summary.scalar("Training Accuracy", accuracy)

# Create summaries to visualize weights
for var in tf.trainable_variables():
    tf.summary.histogram(var.name, var)

# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as session:
    session.run(init)
    step = 0
    offset = random.randint(0,n_input+1)
    end_offset = n_input + 1
    acc_total = 0
    loss_total = 0

    writer.add_graph(session.graph)


    while step < training_iters:
        # Generate a minibatch. Add some randomness on selection process.
        if offset > (len(training_data)-end_offset):
            offset = random.randint(0, n_input+1)

        symbols_in_keys = [ [dictionary[ str(training_data[i])]] for i in range(offset, offset+n_input) ]
        symbols_in_keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])

        symbols_out_onehot = np.zeros([vocab_size], dtype=float)
        symbols_out_onehot[dictionary[str(training_data[offset+n_input])]] = 1.0
        symbols_out_onehot = np.reshape(symbols_out_onehot,[1,-1])

        _, acc, loss, onehot_pred = session.run([optimizer, accuracy, cost, pred], \
                                                feed_dict={x: symbols_in_keys, y: symbols_out_onehot})
        loss_total += loss
        acc_total += acc
        if (step+1) % display_step == 0:
            print("Iter= " + str(step+1) + ", Average Loss= " + \
                  "{:.6f}".format(loss_total/display_step) + ", Average Accuracy= " + \
                  "{:.2f}%".format(100*acc_total/display_step))
            acc_total = 0
            loss_total = 0
            symbols_in = [training_data[i] for i in range(offset, offset + n_input)]
            symbols_out = training_data[offset + n_input]
            symbols_out_pred = reverse_dictionary[int(tf.argmax(onehot_pred, 1).eval())]
            print("%s - [%s] vs [%s]" % (symbols_in,symbols_out,symbols_out_pred))
        step += 1
        offset += (n_input+1)
    print("Optimization Finished!")
    print("Elapsed time: ", elapsed(time.time() - start_time))
    print("Run on command line.")
    print("\ttensorboard --logdir=%s" % (logs_path))
    print("Point your web browser to: http://localhost:6006/")
    while True:
        prompt = "%s words: " % n_input
        sentence = input(prompt)
        sentence = sentence.strip()
        words = sentence.split(' ')
        if len(words) != n_input:
            continue
        try:
            symbols_in_keys = [dictionary[str(words[i])] for i in range(len(words))]
            for i in range(32):
                keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])
                onehot_pred = session.run(pred, feed_dict={x: keys})
                onehot_pred_index = int(tf.argmax(onehot_pred, 1).eval())
                sentence = "%s %s" % (sentence,reverse_dictionary[onehot_pred_index])
                symbols_in_keys = symbols_in_keys[1:]
                symbols_in_keys.append(onehot_pred_index)
            print(sentence)
        except:
            print("Word not in dictionary")
# Out:
# Loaded training data...
# INFO:tensorflow:Summary name Model Loss is illegal; using Model_Loss instead.
# INFO:tensorflow:Summary name Training Accuracy is illegal; using Training_Accuracy instead.
# INFO:tensorflow:Summary name Variable:0 is illegal; using Variable_0 instead.
# INFO:tensorflow:Summary name Variable_1:0 is illegal; using Variable_1_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 is illegal; using bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/bias:0 is illegal; using bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 is illegal; using bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/bias:0 is illegal; using bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 is illegal; using bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/bias:0 is illegal; using bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 is illegal; using bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/bias:0 is illegal; using bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/bias_0 instead.
# Iter= 1000, Average Loss= 4.330925, Average Accuracy= 8.20%
# ['at', 'one', 'another'] - [and] vs [well]
# Iter= 2000, Average Loss= 2.855022, Average Accuracy= 23.70%
# ['to', 'bell', 'the'] - [cat] vs [cat]
# Iter= 3000, Average Loss= 2.661891, Average Accuracy= 30.50%
# ['general', 'applause', ','] - [until] vs [until]
# Iter= 4000, Average Loss= 2.314110, Average Accuracy= 42.40%
# ['neighbourhood', '.', 'this'] - [proposal] vs [proposal]
# Iter= 5000, Average Loss= 1.945789, Average Accuracy= 49.50%
# ['when', 'she', 'was'] - [about] vs [about]
# Iter= 6000, Average Loss= 1.941866, Average Accuracy= 53.30%
# [',', 'and', 'attached'] - [by] vs [by]
# Iter= 7000, Average Loss= 1.559307, Average Accuracy= 61.40%
# ['therefore', ',', 'to'] - [propose] vs [propose]
# Iter= 8000, Average Loss= 1.420730, Average Accuracy= 66.20%
# ['of', 'her', 'approach'] - [,] vs [,]
# Iter= 9000, Average Loss= 1.431109, Average Accuracy= 68.90%
# ['danger', 'consists', 'in'] - [the] vs [which]
# Iter= 10000, Average Loss= 1.273382, Average Accuracy= 71.30%
# ['.', 'you', 'will'] - [all] vs [all]
# Iter= 11000, Average Loss= 1.217019, Average Accuracy= 71.60%
# ['would', 'meet', 'the'] - [case] vs [case]
# Iter= 12000, Average Loss= 0.993047, Average Accuracy= 75.40%
# ['said', 'this', ','] - [and] vs [and]
# Iter= 13000, Average Loss= 0.902715, Average Accuracy= 77.90%
# ['they', 'could', 'take'] - [to] vs [their]
# Iter= 14000, Average Loss= 0.880032, Average Accuracy= 78.40%
# ['long', 'ago', ','] - [the] vs [the]
# Iter= 15000, Average Loss= 0.937183, Average Accuracy= 77.40%
# ['the', 'old', 'mouse'] - [said] vs [said]
# Iter= 16000, Average Loss= 0.729809, Average Accuracy= 82.20%
# ['cat', '?', 'the'] - [mice] vs [mice]
# Iter= 17000, Average Loss= 0.769934, Average Accuracy= 81.20%
# ['with', 'general', 'applause'] - [,] vs [another]
# Iter= 18000, Average Loss= 0.677182, Average Accuracy= 82.50%
# ['about', ',', 'and'] - [could] vs [propose]
# Iter= 19000, Average Loss= 0.835541, Average Accuracy= 79.60%
# ['round', 'the', 'neck'] - [of] vs [of]
# Iter= 20000, Average Loss= 0.706791, Average Accuracy= 83.40%
# ['attached', 'by', 'a'] - [ribbon] vs [ribbon]
# Iter= 21000, Average Loss= 0.930251, Average Accuracy= 78.70%
# ['.', 'i', 'venture'] - [,] vs [all]
# Iter= 22000, Average Loss= 0.824820, Average Accuracy= 81.90%
# ['of', 'her', 'approach'] - [,] vs [,]
# Iter= 23000, Average Loss= 0.795563, Average Accuracy= 82.60%
# ['case', '.', 'you'] - [will] vs [will]
# Iter= 24000, Average Loss= 0.713095, Average Accuracy= 83.60%
# ['last', 'a', 'young'] - [mouse] vs [mouse]
# Iter= 25000, Average Loss= 0.626880, Average Accuracy= 85.90%
# ['common', 'enemy', ','] - [the] vs [the]
# Iter= 26000, Average Loss= 0.675075, Average Accuracy= 85.60%
# ['mice', 'had', 'a'] - [general] vs [general]
# Iter= 27000, Average Loss= 0.714025, Average Accuracy= 83.80%
# ['spoke', '.', 'then'] - [the] vs [the]
# Iter= 28000, Average Loss= 0.608671, Average Accuracy= 86.10%
# ['all', 'very', 'well'] - [,] vs [general]
# Iter= 29000, Average Loss= 0.776998, Average Accuracy= 83.40%
# ['proposal', 'met', 'with'] - [general] vs [and]
# Iter= 30000, Average Loss= 0.645944, Average Accuracy= 85.20%
# ['retire', 'while', 'she'] - [was] vs [was]
# Iter= 31000, Average Loss= 0.625225, Average Accuracy= 85.60%
# ['by', 'this', 'means'] - [we] vs [we]
# Iter= 32000, Average Loss= 0.648438, Average Accuracy= 84.40%
# ['to', 'propose', 'that'] - [a] vs [a]
# Iter= 33000, Average Loss= 0.559981, Average Accuracy= 87.30%
# ['us', '.', 'now'] - [,] vs [,]
# Iter= 34000, Average Loss= 0.695623, Average Accuracy= 84.50%
# ['consists', 'in', 'the'] - [sly] vs [sly]
# Iter= 35000, Average Loss= 0.512795, Average Accuracy= 89.00%
# ['you', 'will', 'all'] - [agree] vs [agree]
# Iter= 36000, Average Loss= 0.665383, Average Accuracy= 85.70%
# ['he', 'had', 'a'] - [proposal] vs [proposal]
# Iter= 37000, Average Loss= 0.680092, Average Accuracy= 85.00%
# [',', 'and', 'some'] - [said] vs [said]
# Iter= 38000, Average Loss= 0.526464, Average Accuracy= 88.10%
# ['measures', 'they', 'could'] - [take] vs [take]
# Iter= 39000, Average Loss= 0.628538, Average Accuracy= 88.00%
# ['to', 'propose', 'impossible'] - [remedies] vs [remedies]
# Iter= 40000, Average Loss= 0.564494, Average Accuracy= 87.30%
# ['another', 'and', 'nobody'] - [spoke] vs [spoke]
# Iter= 41000, Average Loss= 0.602498, Average Accuracy= 87.30%
# ['the', 'cat', '?'] - [the] vs [the]
# Iter= 42000, Average Loss= 0.540132, Average Accuracy= 88.00%
# [',', 'but', 'who'] - [is] vs [is]
# Iter= 43000, Average Loss= 0.501579, Average Accuracy= 89.20%
# ['up', 'and', 'said'] - [that] vs [he]
# Iter= 44000, Average Loss= 0.544375, Average Accuracy= 88.90%
# ['in', 'the', 'neighbourhood'] - [.] vs [.]
# Iter= 45000, Average Loss= 0.534283, Average Accuracy= 88.70%
# ['she', 'was', 'in'] - [the] vs [the]
# Iter= 46000, Average Loss= 0.540449, Average Accuracy= 88.00%
# ['when', 'she', 'was'] - [about] vs [in]
# Iter= 47000, Average Loss= 0.536700, Average Accuracy= 88.40%
# ['ribbon', 'round', 'the'] - [neck] vs [neck]
# Iter= 48000, Average Loss= 0.434833, Average Accuracy= 90.10%
# ['easily', 'escape', 'from'] - [her] vs [her]
# Iter= 49000, Average Loss= 0.580375, Average Accuracy= 87.50%
# ['receive', 'some', 'signal'] - [of] vs [of]
# Iter= 50000, Average Loss= 0.531621, Average Accuracy= 88.10%
# [',', 'said', 'he'] - [,] vs [,]
# Optimization Finished!
# Elapsed time:  5.903526711463928 min
# Run on command line.
# 	tensorboard --logdir=log/
# Point your web browser to: http://localhost:6006/
# 3 words: easily escape from
# easily escape from , and propose that a small bell be procured , and propose that a small bell be procured , and propose that a small bell be procured , and propose that a
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7d7bd11b2bcc> in <module>()
#     191     while True:
#     192         prompt = "%s words: " % n_input
# --> 193         sentence = input(prompt)
#     194         sentence = sentence.strip()
#     195         words = sentence.split(' ')
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
